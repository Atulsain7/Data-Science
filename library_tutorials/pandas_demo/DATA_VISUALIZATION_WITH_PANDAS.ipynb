# %% [markdown]
# > # <font color='rainbow'> <span styel=''>DATA VISUALIZATION WITH PANDAS<font>

# %% [markdown]
# ***

# %% [markdown]
# **Importing Libraries**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# help()()

# %%
from numpy.random import randn,randint,uniform,sample

# %%
df=pd.DataFrame(randn(1000),index=pd.date_range('2019-06-02',periods=1000),columns=['values'])
ts=pd.Series(randn(1000),index=pd.date_range('2019-06-02',periods=1000))

# %%
df['values']=df['values'].cumsum()
df.head(3)
# Out:
#               values
# 2019-06-02 -0.420849
# 2019-06-03  0.291986
# 2019-06-04 -0.832360

# %%
ts=ts.cumsum()
ts.head(3)
# Out:
# 2019-06-02   -0.160410
# 2019-06-03   -0.937091
# 2019-06-04    0.064196
# Freq: D, dtype: float64

# %%
type(df),type(ts)
# Out:
# (pandas.core.frame.DataFrame, pandas.core.series.Series)

# %%
ts.plot()
df.plot()
# Out:
# <AxesSubplot:>

# %%
plt.plot(ts)
plt.plot(df)

# %%
ts.plot(figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
df.plot(figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
iris=sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.plot(subplots=True,figsize=(10,6),grid=True,title='iris dataset')
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)

# %%
ts.plot(kind='line')
# Out:
# <AxesSubplot:>

# %%
df=iris.drop(['species'],axis=1,inplace=False)

# %%
df.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2

# %%
df.iloc[0].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.iloc[0].plot.bar()
# Out:
# <AxesSubplot:>

# %%
titanic=sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic['pclass'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df=pd.DataFrame(randn(10,4),columns=['a','b','c','d'])
df.head()
# Out:
#           a         b         c         d
# 0 -1.414040 -0.160896  0.706777  0.146583
# 1 -2.258554 -0.546174 -0.596775 -0.766458
# 2 -0.012794  0.893595 -0.924492 -0.788756
# 3  0.309942 -1.621622 -1.115578  0.247115
# 4 -0.982649  0.734530  0.526974 -0.141803

# %%
df.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='bar',stacked=True)
# Out:
# <AxesSubplot:>

# %%
df.plot.barh(stacked=True)
# Out:
# <AxesSubplot:>

# %%
iris.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind='hist',stacked=True,bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind='hist',stacked=True,orientation='horizontal')
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %%
iris['sepal_width'].diff().plot(kind='hist',stacked=True,bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df=iris.drop(['species'],axis=1,inplace=False)
df.diff().hist(color='r',alpha=0.5,figsize=(10,10))
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
color={'boxes':'DarkGreen','whiskers':'r'}
df.plot(kind='box',figsize=(10,5),grid=True,color=color)
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='box',figsize=(10,4),grid=True,color=color,vert=False)
# Out:
# <AxesSubplot:>

# %%
df.plot.area()
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='area')
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='area',stacked=False)
# Out:
# <AxesSubplot:>

# %%
df.plot.scatter(x='sepal_length',y='petal_length')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.scatter(x='sepal_length',y='petal_length',c='sepal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
ax=df.plot.scatter(x='sepal_length',y='petal_length',label='Length',xlabel='sepal',ylabel='petal')
df.plot.scatter(x='sepal_width',y='petal_width',label='Width',color='r',ax=ax,xlabel='sepal',ylabel='petal')
# Out:
# <AxesSubplot:xlabel='sepal', ylabel='petal'>

# %%
df.plot.scatter(x='sepal_length',y='sepal_width',c='petal_length',s=df['petal_width']*50)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
df.plot.hexbin(x='sepal_length',y='petal_length',gridsize=25) # color controlled by no of datapoints
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.hexbin(x='sepal_length',y='petal_length',gridsize=25,C='sepal_width') # Color controlled by 'sepal_width'
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
d=df.iloc[0]

# %%
d
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
d.plot(kind='pie',figsize=(5,5))
# Out:
# <AxesSubplot:ylabel='0'>

# %%
d=df.head(3).T
d
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
d.plot.pie(subplots=True,figsize=(20,20),fontsize=16,autopct='%.2f')
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>], dtype=object)

# %%
series=pd.Series([0.1]*4,index=['a','b','c','d'],name='pie plot')
colors = ['pink', 'silver', 'purple','steelblue']
explode = (0.05, 0.2, 0.05,0.05)
series.plot.pie(colors=colors,shadow=True,explode=explode)
# Out:
# <AxesSubplot:ylabel='pie plot'>

# %%
from pandas.plotting import scatter_matrix

# %%
df.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2

# %%
scatter_matrix(df,figsize=(12,12),diagonal='kde',color='red')
plt.show()

# %%
ts.head(3)
# Out:
# 2019-06-02   -0.160410
# 2019-06-03   -0.937091
# 2019-06-04    0.064196
# Freq: D, dtype: float64

# %%
ts.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
from pandas.plotting import andrews_curves # for plotting forier coefficients

# %%
andrews_curves(df,'sepal_width')
# Out:
# <AxesSubplot:>

# %%
ts.plot(style='r--',label='Series',legend=True)
# Out:
# <AxesSubplot:>

# %%
df.plot(legend=False,figsize=(10,5),logy=True,secondary_y=True) #just for demonstration
# Out:
# <AxesSubplot:>

# %%
x=df.drop(['sepal_width','petal_width'],axis=1,inplace=False)
x.head(0)
# Out:
# Empty DataFrame
# Columns: [sepal_length, petal_length]
# Index: []

# %%
y=df.drop(['sepal_length','petal_length'],axis=1,inplace=False)
y.head(0)
# Out:
# Empty DataFrame
# Columns: [sepal_width, petal_width]
# Index: []

# %%
k=x.plot(figsize=(16,5))
y.plot(figsize=(16,5),ax=k,secondary_y=True)
# Out:
# <AxesSubplot:>

# %%
x.plot(figsize=(10,5),x_compat=True)
# Out:
# <AxesSubplot:>

# %%
df.plot(subplots=True,figsize=(10,5),sharex=False,layout=(2,3))
plt.tight_layout()
